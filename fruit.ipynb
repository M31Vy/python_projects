# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 17.8 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO

# %%
# cp -p /kaggle/input/fruit-kaggle/fruit/fruit.yaml /opt/conda/lib/python3.10/site-packages/ultralytics/cfg/datasets/

# %%
# cp -p /kaggle/input/fruit-kaggle/fruit/fruit.yaml /kaggle/working/

# %%
model = YOLO('yolov9c.pt')
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 257MB/s]

# %%
# !mv /kaggle/input/fruit-kaggle /kaggle/input/fruit_kaggle
# Out:
# mv: cannot move '/kaggle/input/fruit-kaggle' to '/kaggle/input/fruit_kaggle': Read-only file system

# %%
results = model.train(data='/kaggle/input/fruitkaggle/fruit/fruit.yaml', epochs=30, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
# !ls -ld /kaggle/input/fruit-kaggle
# Out:
# drwxr-xr-x 3 nobody nogroup 0 Mar 26 15:27 /kaggle/input/fruit-kaggle

# %%
# !chmod 777 /kaggle/input/fruit-kaggle
# Out:
# chmod: changing permissions of '/kaggle/input/fruit-kaggle': Read-only file system

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# 打印内容
# !cat /kaggle/input/fruit-kaggle/fruit/fruit.yaml

# %%
# !python train.py --img 640 --epochs 30 --data /kaggle/input/fruit-kaggle/fruit/fruit.yaml --weights yolov9c.pt

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.1.34
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
# !ls /opt/conda/lib/python3.10/site-packages/ultralytics/cfg/datasets
# Out:
# Argoverse.yaml	      african-wildlife.yaml  coco8.yaml
# DOTAv1.5.yaml	      brain-tumor.yaml	     crack-seg.yaml
# DOTAv1.yaml	      carparts-seg.yaml      dota8.yaml
# GlobalWheat2020.yaml  coco-pose.yaml	     fruit.yaml
# ImageNet.yaml	      coco.yaml		     open-images-v7.yaml
# Objects365.yaml       coco128-seg.yaml	     package-seg.yaml
# SKU-110K.yaml	      coco128.yaml	     tiger-pose.yaml
# VOC.yaml	      coco8-pose.yaml	     xView.yaml
# VisDrone.yaml	      coco8-seg.yaml

# %%
# !cat /opt/conda/lib/python3.10/site-packages/ultralytics/cfg/datasets/fruit.yaml
# Out:
# path: /kaggle/input/fruit_kaggle/fruit
# train: images/train
# val: images/train
# test: test_zip/test
#
# names:
# 0: apple
# 1: banana
# 2: orange

# %%
# !ls

# %%
model.save('/kaggle/working/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.save('/kaggle/working/')
#
# NameError: name 'model' is not defined

# %%
dir(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dir(model)
#
# NameError: name 'model' is not defined

# %%
# !git init
# Out:
# Initialized empty Git repository in /kaggle/working/.git/

# %%
# !git add .

# %%
# !git commit -m 'yolo-fruit'
# Out:
# [master (root-commit) d5a9506] yolo-fruit
#  64 files changed, 4340 insertions(+)
#  create mode 100644 runs/detect/train/F1_curve.png
#  create mode 100644 runs/detect/train/PR_curve.png
#  create mode 100644 runs/detect/train/P_curve.png
#  create mode 100644 runs/detect/train/R_curve.png
#  create mode 100644 runs/detect/train/args.yaml
#  create mode 100644 runs/detect/train/confusion_matrix.png
#  create mode 100644 runs/detect/train/confusion_matrix_normalized.png
#  create mode 100644 runs/detect/train/events.out.tfevents.1711478865.e3287584bd4b.35.0
#  create mode 100644 runs/detect/train/labels.jpg
#  create mode 100644 runs/detect/train/labels_correlogram.jpg
#  create mode 100644 runs/detect/train/results.csv
#  create mode 100644 runs/detect/train/results.png
#  create mode 100644 runs/detect/train/train_batch0.jpg
#  create mode 100644 runs/detect/train/train_batch1.jpg
#  create mode 100644 runs/detect/train/train_batch2.jpg
# ...

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git config --global user.email "157212985@qq.com"
# !git config --global user.name "M31Vy"

# %%
# !git log
# Out:
# commit d5a9506eb95fcb7b7c97f9bd87066b56c6ad8243 (HEAD -> master)
# Author: M31Vy <157212985@qq.com>
# Date:   Tue Mar 26 19:17:58 2024 +0000
#
#     yolo-fruit

# %%
# !git remote add origin git@github.com:M31Vy/python_projects.git
# Out:
# fatal: remote origin already exists.

# %% [markdown]
# ## !git push -u origin master

# %%
# !git push https://M31Vy:52691067Vy@github.com/M31Vy/python_projects.git --all
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/M31Vy/python_projects.git/'

# %%
# !yolo task=detect mode=export model=runs/detect/train/weights/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.1.2 CPU (Intel Xeon 2.00GHz)
# YOLOv9c summary (fused): 384 layers, 25321561 parameters, 0 gradients, 102.3 GFLOPs
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (49.2 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 3.6s, saved as 'runs/detect/train/weights/best.onnx' (96.9 MB)
#
# Export complete (7.8s)
# Results saved to /kaggle/working/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.onnx imgsz=640 data=/kaggle/input/fruitkaggle/fruit/fruit.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export
